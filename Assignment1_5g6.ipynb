# %% [markdown]
# <a href="https://colab.research.google.com/github/19k41a05g6/AI/blob/main/Assignment1_5g6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Assignment*-1
#
# 19K41A05G6 - TEAM 14
#
# Q3. Find stem and lemma words

# %%
import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.tokenize import word_tokenize
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
list1 = ['cats','trouble','troubling','troubled','having','Corriendo','at','was']

# stemming
porter = PorterStemmer()
print("Stem Words: ")
for words in list1:
  stemword = porter.stem(words)
  print(stemword)
# Out:
# Stem Words:
# cat
# troubl
# troubl
# troubl
# have
# corriendo
# at
# wa

# %%
# lemmatization
lemma = WordNetLemmatizer()
print("Lemma Words: ")
for words in list1:
  lemma_word = lemma.lemmatize(words)
  print(lemma_word)
# Out:
# Lemma Words:
# cat
# trouble
# troubling
# troubled
# having
# Corriendo
# at
# wa

# %% [markdown]
#   Q8.Find BoW for the paragraph and also find stem and lemma words

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

# %%
paragraph = "Text Summarization is one of those applications of Natural Language Processing (NLP) which is bound to have a huge impact on our lives. With growing digital media and ever-growing publishing – who has the time to go through entire articles / documents / books to decide whether they are useful or not? Thankfully – this technology is already here."
count_vec = CountVectorizer()
count_occurs = count_vec.fit_transform([paragraph])

# %%
count_occur_df = pd.DataFrame((count, word) for word, count in zip(count_occurs.toarray().tolist()[0], count_vec.get_feature_names()))
count_occur_df.columns = ['word','count']
count_occur_df.sort_values('count', ascending = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#              word  count
# 0         already      1
# 25            not      1
# 27             on      1
# 28            one      1
# 29             or      1
# 30            our      1
# 31     processing      1
# 32     publishing      1
# 33  summarization      1
# 34     technology      1
# 47            who      1
# 35           text      1
# 37            the      1
# 38           they      1
# 39           this      1
# 40          those      1
# 41        through      1
# 42           time      1
# 44         useful      1
# 45        whether      1
# 46          which      1
# 36     thankfully      1
# 23        natural      1
# 24            nlp      1
# 21          lives      1
# ...

# %%
# stemming
word_list = nltk.word_tokenize(paragraph)
for word in word_list:
  root = porter.stem(word)
  print(root)
# Out:
# text
# summar
# is
# one
# of
# those
# applic
# of
# natur
# languag
# process
# (
# nlp
# )
# which
# is
# bound
# to
# have
# a
# huge
# impact
# on
# our
# live
# .
# with
# grow
# digit
# media
# and
# ever-grow
# publish
# –
# who
# ha
# the
# time
# to
# go
# through
# entir
# articl
# /
# document
# /
# book
# to
# decid
# whether
# they
# are
# use
# or
# not
# ?
# thank
# –
# thi
# technolog
# is
# alreadi
# here
# .

# %%
# lemmatization
for word in word_list:
  root = lemma.lemmatize(word)
  print(root)
# Out:
# Text
# Summarization
# is
# one
# of
# those
# application
# of
# Natural
# Language
# Processing
# (
# NLP
# )
# which
# is
# bound
# to
# have
# a
# huge
# impact
# on
# our
# life
# .
# With
# growing
# digital
# medium
# and
# ever-growing
# publishing
# –
# who
# ha
# the
# time
# to
# go
# through
# entire
# article
# /
# document
# /
# book
# to
# decide
# whether
# they
# are
# useful
# or
# not
# ?
# Thankfully
# –
# this
# technology
# is
# already
# here
# .
